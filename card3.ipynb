# %%
import pandas as pd
import os
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#MAC font setting for mpl
mpl.rcParams['axes.unicode_minus'] = False 
mpl.rcParams['font.family'] = "AppleGothic"

# %%
path = os.path.join("card_data_final_3.xlsx")
path
# Out:
# 'card_data_final_3.xlsx'

# %%
df = pd.read_excel(path, sheet_name=0)
df
# Out:
#        순번                  거래일시  사용 금액    거래후잔액    거래내용       거래기록사항  \
# 0    1012  2020/02/25\n15:22:31  19400   476554  NHBC체크     한국산업인력공단
# 1     134  2020/11/12\n16:03:09  22600    84545  NHBC체크     한국산업인력공단
# 2     136  2020/11/12\n14:54:59  22600    84545  NHBC체크     한국산업인력공단
# 3     363  2020/09/14\n11:08:15  22600    24432  NHBC체크     한국산업인력공단
# 4     441  2020/08/23\n14:37:11   6000  1295439  NHBC체크     IFC서울관리단
# 5     833  2020/04/12\n12:48:06  15000    60019  NHBC체크      후암시장주차장
# 6     436  2020/08/23\n22:47:15   7500  1264219  NHBC체크    하이파킹_KICC
# 7     509  2020/07/30\n23:44:45    600   176225  NHBC체크       파킹클라우드
# 8     607  2020/07/09\n19:59:03   3800   501157  NHBC체크    티머니택시(법인)
# 9     865  2020/04/03\n16:37:49   6500   426924  NHBC체크    티머니택시(법인)
# 10    618  2020/07/06\n21:05:24   7400    37990  NHBC체크    티머니택시(법인)
# 11    263  2020/10/06\n10:29:42   3800   282474  NHBC체크    티머니택시(개인)
# 12   1145  2020/01/12\n03:12:35   7100     9170  NHBC체크    티머니택시(개인)
# 13    921  2020/03/21\n02:06:55   7400   846775  NHBC체크    티머니택시(개인)
# 14    570  2020/07/13\n23:07:59   5500   196630  NHBC체크     택시-스마트로1
# 15    402  2020/09/03\n14:19:14  18000   289580  S-신한은행            퀵
# 16    188  2020/11/01\n10:59:37   1800    21264  NHBC체크    코레일유통주식회사
# 17    237  2020/10/15\n16:40:57    900   277774  NHBC체크  코레일네트웍스(주)대
# 18    228  2020/10/18\n22:27:45   1800   253274  NHBC체크  코레일네트웍스(주)대
# 19    547  2020/07/15\n11:16:26   3300    98330  NHBC체크    카카오페이(택시)
# 20    548  2020/07/15\n11:10:07   3600   101630  NHBC체크    카카오페이(택시)
# 21    588  2020/07/12\n16:25:32   3800   486390  NHBC체크    카카오페이(택시)
# 22    563  2020/07/14\n15:24:57   4000    71230  NHBC체크    카카오페이(택시)
# 23    559  2020/07/14\n19:35:04   4200    29930  NHBC체크    카카오페이(택시)
# 24    589  2020/07/12\n16:17:18   4600   490190  NHBC체크    카카오페이(택시)
# 25    277  2020/10/02\n11:16:24   4700   472208  NHBC체크    카카오페이(택시)
# 26    558  2020/07/14\n19:50:08   4900    25030  NHBC체크    카카오페이(택시)
# 27    564  2020/07/14\n15:16:54   4900    75230  NHBC체크    카카오페이(택시)
# 28   1169  2020/01/05\n16:44:25   4900    73240  NHBC체크    카카오페이(택시)
# 29    944  2020/03/15\n12:59:52   5600   526955  NHBC체크    카카오페이(택시)
# ..    ...                   ...    ...      ...     ...          ...
# 826  1085  2020/02/05\n16:52:43   4100    39593  NHBC체크  (주)스타벅스커피코리
# 827   806  2020/04/23\n14:19:18   4600   123545  NHBC체크  (주)스타벅스커피코리
# 25   농협\n235095  교통
# 26   농협\n235095  교통
# 27   농협\n235095  교통
# 28   농협\n235095  교통
# 29   농협\n235095  교통
# ..          ...  ..
# 826  농협\n235095  커피
# 827  농협\n235095  커피
# 828  농협\n235095  커피
# 829  농협\n235095  커피
# 830  농협\n235095  커피
# 831  농협\n235095  커피
# 832  농협\n235095  커피
# 833  농협\n235095  커피
# 834  농협\n235095  커피
# 835  농협\n235095  커피
# 836  농협\n235095  커피
# 837  농협\n235095  커피
# 838  농협\n235095  커피
# 839  농협\n235095  커피
# 840  농협\n235095  커피
# 841  농협\n235095  커피
# 842  농협\n235095  커피
# 843  농협\n235095  커피
# 844  농협\n235095  항공
# 845  농협\n235095  항공
# 846  농협\n235095  항공
# 847  농협\n235095  항공
# 848  농협\n235095  항공
# 849  농협\n235095  항공
# 850  농협\n235095  항공
# 851  농협\n235095  항공
# 852  농협\n235095  항공
# 853  농협\n235095  항공
# 854  농협\n235095  항공
# 855  농협\n235095  항공
#
# [856 rows x 8 columns]

# %%
#df_loc.info()

# %%
df.loc[:,'사용 건수'] = 1

# %%
b_grouped_count = df['사용 건수'].groupby(df['업종'])
grouped_count = b_grouped_count.sum()
category_count = grouped_count.to_frame()
category_count = category_count.sort_values(by=['사용 건수'], ascending=False)
category_count
# Out:
#        사용 건수
# 업종
# 커피       263
# 쇼핑       198
# 외식       144
# 레져       103
# 교통        83
# 영화/공연     20
# 주유        12
# 항공        12
# 뷰티         7
# 교육         4
# 베이커리       4
# 도서         2
# 여행         2
# 기타         1
# 의료         1

# %%
b_grouped_amount = df['사용 금액'].groupby(df['업종'])
grouped_amount = b_grouped_amount.sum()
category_amount = grouped_amount.to_frame()
category_amount = category_amount.sort_values(by=['사용 금액'], ascending=False)
category_amount
# Out:
#          사용 금액
# 업종
# 외식     3963250
# 쇼핑     3180712
# 커피     1589550
# 레져      646800
# 교통      619080
# 항공      422900
# 영화/공연   268664
# 주유      144000
# 뷰티      112850
# 교육       87200
# 베이커리     57750
# 여행       56000
# 도서       16500
# 의료        4500
# 기타        2100

# %%
category = pd.merge(category_count,category_amount, on="업종")
category = category.sort_values(by=['사용 금액'], ascending=False)
category
# Out:
#        사용 건수    사용 금액
# 업종
# 외식       144  3963250
# 쇼핑       198  3180712
# 커피       263  1589550
# 레져       103   646800
# 교통        83   619080
# 항공        12   422900
# 영화/공연     20   268664
# 주유        12   144000
# 뷰티         7   112850
# 교육         4    87200
# 베이커리       4    57750
# 여행         2    56000
# 도서         2    16500
# 의료         1     4500
# 기타         1     2100

# %%
category['사용 건수'].plot(kind="bar")

# %%
category['사용 건수'].plot(kind="pie")

# %%
category['사용 금액'].plot(kind="bar")

# %%
df_category = category[0:5]
df_category
# Out:
#     사용 건수    사용 금액
# 업종
# 외식    144  3963250
# 쇼핑    198  3180712
# 커피    263  1589550
# 레져    103   646800
# 교통     83   619080

# %%
# 사용금액 TOP 5
colors = ['#FD7400', '#004358', '#FFE11A','#BF0917', '#1F8A70']

plt.pie(df_category['사용 금액'], shadow=False, colors=colors, startangle=90)
plt.axis('equal')
plt.legend(df_category.index, loc='lower center', ncol=5, bbox_to_anchor=(0.5, -0.30))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
